# %%
import os
a="./daniel"
list_files=os.listdir(a)
print(list_files)
# Out:
# ['apr_sales.csv', 'aug_sales.csv', 'dec_sales.csv', 'feb_sales.csv', 'fun.jpg', 'jan_sales.csv', 'jul_sales.csv', 'jun_sales.csv', 'mar_sales.csv', 'may_sales.csv', 'nov_sales.csv', 'oct_sales.csv', 'progress.txt', 'sep_sales.csv', 'status.xlsx']

# %%
import os
import glob
import pandas as pd
a="./daniel"
files=os.path.join(a,"*csv")
csv_files=glob.glob(files)
df=[pd.read_csv(file) for file in csv_files]
year=pd.concat(df,ignore_index=True)
print(year)
print(year["Product_Cost"].sum())
# Out:
#      Order_Id Customer_Name  Customer_Id                Product_Name  \
# 0        1320          Venu           23      LG ThinQ Refrigerator
# 1        1321  Jaya Chandra           21  Bose SoundSport Headphones
# 2        1322   Mallikarjun           13    Apple Airpods Headphones
# 3        1323        Siddhu           18      Samsung Galaxy S9 Plus
# 4        1324        Daniel            6                    iPhone 8
# ..        ...           ...          ...                         ...
# 103      1819        Daniel            6          LG Washing Machine
# 104      1820       Neelima           19                20in Monitor
# 105      1821       Karteek            4                20in Monitor
# 106      1822  Jaya Chandra           21      LG ThinQ Refrigerator
# 107      1823    Chaithanya           14            27in FHD Monitor
#
#      Product_Cost             Date
# 0           55000   4/11/2019 9:00
# 1           63000  4/13/2019 10:00
# ...

# %%
import matplotlib.pyplot as plt
a=[10,11,12,25,25,27,31,33,34,34,35,36,43,50,59]
plt.boxplot(a)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x21ed44116d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x21ed4411810>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x21ed43b1450>],
#  'medians': [<matplotlib.lines.Line2D at 0x21ed4411a90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x21ed4411bd0>],
#  'means': []}

# %%
import pandas as pd
df=pd.read_csv("sales8.csv")
df
# Out:
#     Order Id Customer name  Customer Id                Product name  \
# 0     192837         Veeru            3                   LG Mobile
# 1     192838       Neelima           19        Apple iPad 10.2-inch
# 2     192839        Balaji           12      34in Ultrawide Monitor
# 3     192840        Shahid           20                   iPhone 11
# 4     192841         Vinay           10  Bose SoundSport Headphones
# 5     192842         Vinay           10                20in Monitor
# 6     192843        Balaji           12                    iPhone 8
# 7     192844    Nireekshan            1      27in 4K Gaming Monitor
# 8     192845          Venu           23                    iPhone 9
# 9     192846         Veeru            3                20in Monitor
# 10    192847     Madhurima            7               Flatscreen TV
# 11    192848         Kedar            2               Flatscreen TV
# 12    192849          Venu           23          Samsung Galaxy S20
# ...

# %%
cond1=df["Customer name"]=="Veeru"
(df[cond1])
# Out:
#     Order Id Customer name  Customer Id        Product name  Product cost  \
# 0     192837         Veeru            3           LG Mobile         65999
# 9     192846         Veeru            3        20in Monitor         63000
# 15    192852         Veeru            3            iPhone 9         60000
# 24    192861         Veeru            3  Samsung Galaxy S20         51999
#
#     Quantity
# 0          1
# 9          1
# 15         2
# 24         2

# %%
cond1=df["Product name"]=="iPhone 9"
df[cond1]
# Out:
#     Order Id Customer name  Customer Id Product name  Product cost  Quantity
# 8     192845          Venu           23     iPhone 9         55999         2
# 15    192852         Veeru            3     iPhone 9         60000         2

# %%
a=["LG Mobile","20in Monitor","Samsung Galaxy S20"]
b=df["Product name"].isin(a)
df1=df[b]
df1
# Out:
#     Order Id Customer name  Customer Id        Product name  Product cost  \
# 0     192837         Veeru            3           LG Mobile         65999
# 5     192842         Vinay           10        20in Monitor         65999
# 9     192846         Veeru            3        20in Monitor         63000
# 12    192849          Venu           23  Samsung Galaxy S20         65999
# 17    192854   Mallikarjun           13           LG Mobile         65999
# 24    192861         Veeru            3  Samsung Galaxy S20         51999
#
#     Quantity
# 0          1
# 5          2
# 9          1
# 12         2
# 17         1
# 24         2

# %%
import pandas as pd
df=pd.read_csv("sales4.csv")
df
# Out:
#         Order_Id Customer_Name  Customer_Id                Product_Name  \
# 0           1023         Venki           15            27in FHD Monitor
# 1           1024    Chaithanya           14                   iPhone 11
# 2           1025        Shahid           20  Bose SoundSport Headphones
# 3           1026         Veeru            3        Apple iPad 10.2-inch
# 4           1027          Venu           23                Google Phone
# ...          ...           ...          ...                         ...
# 299995    301018       Karteek            4        Apple iPad 10.2-inch
# 299996    301019         Veeru            3          Macbook Pro Laptop
# 299997    301020        Harsha            5          LG Washing Machine
# 299998    301021    Nireekshan            1                   LG Mobile
# 299999    301022       Pradhan           17      34in Ultrawide Monitor
#
#         Product_Cost
# 0              59000
# 1              69000
# 2              65999
# ...

# %%
cond1=df["Product_Cost"]>70000
df[cond1]
# Out:
#         Order_Id Customer_Name  Customer_Id            Product_Name  \
# 25          1048        Partha            8  Samsung Galaxy S9 Plus
# 28          1051       Lavanya           16      LG Washing Machine
# 42          1065     Madhurima            7            20in Monitor
# 45          1068         Vinay           10  Samsung Galaxy S9 Plus
# 53          1076         Tarun           11      LG Washing Machine
# ...          ...           ...          ...                     ...
# 299955    300978        Siddhu           18  34in Ultrawide Monitor
# 299963    300986        Shahid           20  34in Ultrawide Monitor
# 299964    300987        Harsha            5      Macbook Pro Laptop
# 299965    300988     Madhurima            7           Flatscreen TV
# 299973    300996         Vinay           10  Samsung Galaxy S9 Plus
#
#         Product_Cost
# 25             75000
# 28             75000
# 42             75999
# 45             75999
# 53             75999
# ...

# %%
cond1=df["Product_Name"]=="LG Washing Machine"
cond2=df["Customer_Name"]=="Madhurima"
df1=df.loc[cond1&cond2]
df1
# Out:
#         Order_Id Customer_Name  Customer_Id        Product_Name  Product_Cost
# 493         1516     Madhurima            7  LG Washing Machine         65000
# 1347        2370     Madhurima            7  LG Washing Machine         60000
# 1352        2375     Madhurima            7  LG Washing Machine         59000
# 1774        2797     Madhurima            7  LG Washing Machine         61000
# 2160        3183     Madhurima            7  LG Washing Machine         60000
# ...          ...           ...          ...                 ...           ...
# 297957    298980     Madhurima            7  LG Washing Machine         63000
# 299064    300087     Madhurima            7  LG Washing Machine         59000
# 299147    300170     Madhurima            7  LG Washing Machine         63000
# 299651    300674     Madhurima            7  LG Washing Machine         65999
# 299797    300820     Madhurima            7  LG Washing Machine         65999
#
# [575 rows x 5 columns]

# %%
print(df["Product_Name"].unique())
# Out:
# ['27in FHD Monitor' 'iPhone 11' 'Bose SoundSport Headphones'
#  'Apple iPad 10.2-inch' 'Google Phone' 'Samsung Galaxy S9 Plus'
#  '20in Monitor' 'LG Washing Machine' 'iPhone 7s' 'Samsung Galaxy S20'
#  'LG ThinQ Refrigerator ' 'Apple Airpods Headphones' 'iPhone 8'
#  'Macbook Pro Laptop' 'LG Mobile' 'ThinkPad Laptop' 'Flatscreen TV'
#  '34in Ultrawide Monitor' 'iPhone 9' '27in 4K Gaming Monitor']

# %%
import pandas as pd
df=pd.read_csv("sales2.csv")
df
# Out:
#      Order id Customer name  Customer id                Product name  \
# 0      192837        Partha            8        Apple iPad 10.2-inch
# 1      192838         Vinay           10               Flatscreen TV
# 2      192839       Lavanya           16                20in Monitor
# 3      192840         Mohan           24  Bose SoundSport Headphones
# 4      192841         Kedar            2                Google Phone
# ..        ...           ...          ...                         ...
# 895    193732        Balaji           12          Samsung Galaxy S20
# 896    193733       Neelima           19      27in 4K Gaming Monitor
# 897    193734        Siddhu           18                Google Phone
# 898    193735         Vinay           10                20in Monitor
# 899    193736     Madhurima            7            27in FHD Monitor
#
#      Product cost
# 0           59000
# 1           65999
# 2           75000
# 3           55000
# 4           59000
# ..            ...
# ...

# %%
df1=df.iloc[10:20,0:3]
df1
# Out:
#     Order id Customer name  Customer id
# 10    192847       Lavanya           16
# 11    192848       Pradhan           17
# 12    192849        Harsha            5
# 13    192850  Jaya Chandra           21
# 14    192851          Venu           23
# 15    192852         Venki           15
# 16    192853         Tarun           11
# 17    192854         Venki           15
# 18    192855         Vijay            9
# 19    192856         Vijay            9

# %%
df.set_index("Product name",inplace=True)

# %%
df
# Out:
#                             Order id Customer name  Customer id  Product cost
# Product name
# Apple iPad 10.2-inch          192837        Partha            8         59000
# Flatscreen TV                 192838         Vinay           10         65999
# 20in Monitor                  192839       Lavanya           16         75000
# Bose SoundSport Headphones    192840         Mohan           24         55000
# Google Phone                  192841         Kedar            2         59000
# ...                              ...           ...          ...           ...
# Samsung Galaxy S20            193732        Balaji           12         60000
# 27in 4K Gaming Monitor        193733       Neelima           19         75999
# Google Phone                  193734        Siddhu           18         69999
# 20in Monitor                  193735         Vinay           10         69999
# 27in FHD Monitor              193736     Madhurima            7         55999
#
# ...

# %%
rows=["Apple iPad 10.2-inch","20in Monitor"]
cols=["Order id","Customer name"]
df1=df.loc[rows,cols]
df1
# Out:
#                       Order id Customer name
# Product name
# Apple iPad 10.2-inch    192837        Partha
# Apple iPad 10.2-inch    192854         Venki
# Apple iPad 10.2-inch    192869         Kedar
# Apple iPad 10.2-inch    192904       Sumanth
# Apple iPad 10.2-inch    192906         Mohan
# ...                        ...           ...
# 20in Monitor            193662        Harsha
# 20in Monitor            193686     Madhurima
# 20in Monitor            193692         Vinay
# 20in Monitor            193720          Venu
# 20in Monitor            193735         Vinay
#
# [101 rows x 2 columns]

# %%
import pandas as pd
df=pd.read_csv("sales4.csv")
df
# Out:
#         Order_Id Customer_Name  Customer_Id                Product_Name  \
# 0           1023         Venki           15            27in FHD Monitor
# 1           1024    Chaithanya           14                   iPhone 11
# 2           1025        Shahid           20  Bose SoundSport Headphones
# 3           1026         Veeru            3        Apple iPad 10.2-inch
# 4           1027          Venu           23                Google Phone
# ...          ...           ...          ...                         ...
# 299995    301018       Karteek            4        Apple iPad 10.2-inch
# 299996    301019         Veeru            3          Macbook Pro Laptop
# 299997    301020        Harsha            5          LG Washing Machine
# 299998    301021    Nireekshan            1                   LG Mobile
# 299999    301022       Pradhan           17      34in Ultrawide Monitor
#
#         Product_Cost
# 0              59000
# 1              69000
# 2              65999
# ...

# %%
rows=df.index[10:20]
cols=["Customer_Name","Product_Name"]
df2=df.loc[rows,cols]
df2
# Out:
#    Customer_Name              Product_Name
# 10         Vijay                 iPhone 7s
# 11         Tarun        Samsung Galaxy S20
# 12         Kedar              Google Phone
# 13    Chaithanya    LG ThinQ Refrigerator
# 14    Nireekshan  Apple Airpods Headphones
# 15        Daniel        Samsung Galaxy S20
# 16       Karteek    Samsung Galaxy S9 Plus
# 17       Sumanth                  iPhone 8
# 18         Venki        Samsung Galaxy S20
# 19   Mallikarjun              Google Phone

# %%
import pandas as pd
df=pd.read_csv("sales8.csv")
df
# Out:
#     Order Id Customer name  Customer Id                Product name  \
# 0     192837         Veeru            3                   LG Mobile
# 1     192838       Neelima           19        Apple iPad 10.2-inch
# 2     192839        Balaji           12      34in Ultrawide Monitor
# 3     192840        Shahid           20                   iPhone 11
# 4     192841         Vinay           10  Bose SoundSport Headphones
# 5     192842         Vinay           10                20in Monitor
# 6     192843        Balaji           12                    iPhone 8
# 7     192844    Nireekshan            1      27in 4K Gaming Monitor
# 8     192845          Venu           23                    iPhone 9
# 9     192846         Veeru            3                20in Monitor
# 10    192847     Madhurima            7               Flatscreen TV
# 11    192848         Kedar            2               Flatscreen TV
# 12    192849          Venu           23          Samsung Galaxy S20
# ...

# %%
df["totalvalue"]=df["Product cost"]*df["Quantity"]
df
# Out:
#     Order Id Customer name  Customer Id                Product name  \
# 0     192837         Veeru            3                   LG Mobile
# 1     192838       Neelima           19        Apple iPad 10.2-inch
# 2     192839        Balaji           12      34in Ultrawide Monitor
# 3     192840        Shahid           20                   iPhone 11
# 4     192841         Vinay           10  Bose SoundSport Headphones
# 5     192842         Vinay           10                20in Monitor
# 6     192843        Balaji           12                    iPhone 8
# 7     192844    Nireekshan            1      27in 4K Gaming Monitor
# 8     192845          Venu           23                    iPhone 9
# 9     192846         Veeru            3                20in Monitor
# 10    192847     Madhurima            7               Flatscreen TV
# 11    192848         Kedar            2               Flatscreen TV
# 12    192849          Venu           23          Samsung Galaxy S20
# ...

# %%
a="newvalue"
df.insert(3,"addingvalue",a)

# %%
df
# Out:
#     Order Id Customer name  Customer Id addingvalue  \
# 0     192837         Veeru            3    newvalue
# 1     192838       Neelima           19    newvalue
# 2     192839        Balaji           12    newvalue
# 3     192840        Shahid           20    newvalue
# 4     192841         Vinay           10    newvalue
# 5     192842         Vinay           10    newvalue
# 6     192843        Balaji           12    newvalue
# 7     192844    Nireekshan            1    newvalue
# 8     192845          Venu           23    newvalue
# 9     192846         Veeru            3    newvalue
# 10    192847     Madhurima            7    newvalue
# 11    192848         Kedar            2    newvalue
# 12    192849          Venu           23    newvalue
# 13    192850       Neelima           19    newvalue
# 14    192851        Daniel            6    newvalue
# 15    192852         Veeru            3    newvalue
# 16    192853       Lavanya           16    newvalue
# ...

# %%
df.drop(columns="addingvalue",inplace=True)

# %%
df
# Out:
#     Order Id Customer name  Customer Id                Product name  \
# 0     192837         Veeru            3                   LG Mobile
# 1     192838       Neelima           19        Apple iPad 10.2-inch
# 2     192839        Balaji           12      34in Ultrawide Monitor
# 3     192840        Shahid           20                   iPhone 11
# 4     192841         Vinay           10  Bose SoundSport Headphones
# 5     192842         Vinay           10                20in Monitor
# 6     192843        Balaji           12                    iPhone 8
# 7     192844    Nireekshan            1      27in 4K Gaming Monitor
# 8     192845          Venu           23                    iPhone 9
# 9     192846         Veeru            3                20in Monitor
# 10    192847     Madhurima            7               Flatscreen TV
# 11    192848         Kedar            2               Flatscreen TV
# 12    192849          Venu           23          Samsung Galaxy S20
# ...

# %%
cols=["Quantity","totalvalue"]
df.drop(cols,axis=1,inplace=True)

# %%
df
# Out:
#     Order Id Customer name  Customer Id                Product name  \
# 0     192837         Veeru            3                   LG Mobile
# 1     192838       Neelima           19        Apple iPad 10.2-inch
# 2     192839        Balaji           12      34in Ultrawide Monitor
# 3     192840        Shahid           20                   iPhone 11
# 4     192841         Vinay           10  Bose SoundSport Headphones
# 5     192842         Vinay           10                20in Monitor
# 6     192843        Balaji           12                    iPhone 8
# 7     192844    Nireekshan            1      27in 4K Gaming Monitor
# 8     192845          Venu           23                    iPhone 9
# 9     192846         Veeru            3                20in Monitor
# 10    192847     Madhurima            7               Flatscreen TV
# 11    192848         Kedar            2               Flatscreen TV
# 12    192849          Venu           23          Samsung Galaxy S20
# ...

# %%
df.drop([1,5,10,20],axis=0,inplace=True)

# %%
df
# Out:
#     Order Id Customer name  Customer Id                Product name  \
# 0     192837         Veeru            3                   LG Mobile
# 2     192839        Balaji           12      34in Ultrawide Monitor
# 3     192840        Shahid           20                   iPhone 11
# 4     192841         Vinay           10  Bose SoundSport Headphones
# 6     192843        Balaji           12                    iPhone 8
# 7     192844    Nireekshan            1      27in 4K Gaming Monitor
# 8     192845          Venu           23                    iPhone 9
# 9     192846         Veeru            3                20in Monitor
# 11    192848         Kedar            2               Flatscreen TV
# 12    192849          Venu           23          Samsung Galaxy S20
# 13    192850       Neelima           19             ThinkPad Laptop
# 14    192851        Daniel            6      Samsung Galaxy S9 Plus
# 15    192852         Veeru            3                    iPhone 9
# ...

# %%
import pandas as pd
a=[[10,20],
   [30,40]]
b=[[50,60],
   [70,80]]
x=["name","age"]
df1=pd.DataFrame(a,columns=x)
df2=pd.DataFrame(b,columns=x)
y=[df1,df2]
result=pd.concat(y,ignore_index=True)
result
# Out:
#    name  age
# 0    10   20
# 1    30   40
# 2    50   60
# 3    70   80

# %%
import pandas as pd
a=[[10,20],
   [30,40],
   [50,60]]
b=[[10,20],
   [30,40]]
x=["a","b"]
y=["c","d"]
df1=pd.DataFrame(a,columns=x)
df2=pd.DataFrame(b,columns=y)
c=[df1,df2]
result=pd.concat(c,axis=1)
result
# Out:
#     a   b     c     d
# 0  10  20  10.0  20.0
# 1  30  40  30.0  40.0
# 2  50  60   NaN   NaN

# %%
import pandas as pd
df=pd.read_csv("sales7_dates.csv",parse_dates=["Pur_Date"])
df
# Out:
#       Order_Id Customer_Name  Customer_Id                Product_Name  \
# 0         1023         Venki           15            27in FHD Monitor
# 1         1024    Chaithanya           14                   iPhone 11
# 2         1025        Shahid           20  Bose SoundSport Headphones
# 3         1026         Veeru            3        Apple iPad 10.2-inch
# 4         1027          Venu           23                Google Phone
# ...        ...           ...          ...                         ...
# 9994     11017       Karteek            4                20in Monitor
# 9995     11018         Vinay           10    Apple Airpods Headphones
# 9996     11019       Neelima           19      LG ThinQ Refrigerator
# 9997     11020        Siddhu           18                   iPhone 7s
# 9998     11021         Tarun           11      34in Ultrawide Monitor
#
#       Product_Cost            Pur_Date
# 0            59000 2019-01-01 00:00:00
# 1            69000 2019-01-01 01:00:00
# ...

# %%
df["date"]=df["Pur_Date"].dt.date
df["month"]=df["Pur_Date"].dt.month
df["year"]=df["Pur_Date"].dt.year
df["day"]=df["Pur_Date"].dt.weekday+1

# %%
df
# Out:
#       Order_Id Customer_Name  Customer_Id                Product_Name  \
# 0         1023         Venki           15            27in FHD Monitor
# 1         1024    Chaithanya           14                   iPhone 11
# 2         1025        Shahid           20  Bose SoundSport Headphones
# 3         1026         Veeru            3        Apple iPad 10.2-inch
# 4         1027          Venu           23                Google Phone
# ...        ...           ...          ...                         ...
# 9994     11017       Karteek            4                20in Monitor
# 9995     11018         Vinay           10    Apple Airpods Headphones
# 9996     11019       Neelima           19      LG ThinQ Refrigerator
# 9997     11020        Siddhu           18                   iPhone 7s
# 9998     11021         Tarun           11      34in Ultrawide Monitor
#
#       Product_Cost            Pur_Date        date  month  year  day
# ...

# %%
df["Pur_Date"].dt.day_name()
# Out:
# 0       Tuesday
# 1       Tuesday
# 2       Tuesday
# 3       Tuesday
# 4       Tuesday
#          ...
# 9994     Friday
# 9995     Friday
# 9996     Friday
# 9997     Friday
# 9998     Friday
# Name: Pur_Date, Length: 9999, dtype: object

# %%
df["Pur_Date"].dt.weekday+1
# Out:
# 0       2
# 1       2
# 2       2
# 3       2
# 4       2
#        ..
# 9994    5
# 9995    5
# 9996    5
# 9997    5
# 9998    5
# Name: Pur_Date, Length: 9999, dtype: int32

# %%
df
# Out:
#       Order_Id Customer_Name  Customer_Id                Product_Name  \
# 0         1023         Venki           15            27in FHD Monitor
# 1         1024    Chaithanya           14                   iPhone 11
# 2         1025        Shahid           20  Bose SoundSport Headphones
# 3         1026         Veeru            3        Apple iPad 10.2-inch
# 4         1027          Venu           23                Google Phone
# ...        ...           ...          ...                         ...
# 9994     11017       Karteek            4                20in Monitor
# 9995     11018         Vinay           10    Apple Airpods Headphones
# 9996     11019       Neelima           19      LG ThinQ Refrigerator
# 9997     11020        Siddhu           18                   iPhone 7s
# 9998     11021         Tarun           11      34in Ultrawide Monitor
#
#       Product_Cost            Pur_Date        date  month  year  day
# ...

# %%
new=df.set_index("Pur_Date")

# %%
new
# Out:
#                      Order_Id Customer_Name  Customer_Id  \
# Pur_Date
# 2019-01-01 00:00:00      1023         Venki           15
# 2019-01-01 01:00:00      1024    Chaithanya           14
# 2019-01-01 02:00:00      1025        Shahid           20
# 2019-01-01 03:00:00      1026         Veeru            3
# 2019-01-01 04:00:00      1027          Venu           23
# ...                       ...           ...          ...
# 2020-02-21 10:00:00     11017       Karteek            4
# 2020-02-21 11:00:00     11018         Vinay           10
# 2020-02-21 12:00:00     11019       Neelima           19
# 2020-02-21 13:00:00     11020        Siddhu           18
# 2020-02-21 14:00:00     11021         Tarun           11
#
#                                    Product_Name  Product_Cost        date  \
# Pur_Date
# 2019-01-01 00:00:00            27in FHD Monitor         59000  2019-01-01
# 2019-01-01 01:00:00                   iPhone 11         69000  2019-01-01
# ...

# %%
result=df.last('10D')
result
# Out:
# C:\Users\rajes\AppData\Local\Temp\ipykernel_19292\584100608.py:1: FutureWarning: last is deprecated and will be removed in a future version. Please create a mask and filter using `.loc` instead
#   result=df.last('10D')
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19292\584100608.py in ?()
# ----> 1 result=df.last('10D')
#       2 result
#
# ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py in ?(self, offset)
#    9934             stacklevel=find_stack_level(),
#    9935         )
#    9936
#    9937         if not isinstance(self.index, DatetimeIndex):
# -> 9938             raise TypeError("'last' only supports a DatetimeIndex index")
#    9939
#    9940         if len(self.index) == 0:
#    9941             return self.copy(deep=False)
#
# TypeError: 'last' only supports a DatetimeIndex index
